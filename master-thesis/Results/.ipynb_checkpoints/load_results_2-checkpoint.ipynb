# %%
import pandas as pd
import json
import numpy as np
import sys 
import os
import matplotlib.pyplot as plt

# %% [markdown]
# # Compare

# %%
files = os.listdir("json_files/")
files = [file  for file in files if "COMPARISON" in file ]

# %%
files
# Out:
# ['10_COMPARISON.json',
#  '10_COMPARISON_1.json',
#  '10_COMPARISON_2.json',
#  '13_COMPARISON.json',
#  '13_COMPARISON_1.json',
#  '13_COMPARISON_2.json',
#  '16_COMPARISON.json',
#  '16_COMPARISON_1.json',
#  '16_COMPARISON_2.json',
#  '17_COMPARISON.json',
#  '17_COMPARISON_1.json',
#  '17_COMPARISON_2.json',
#  '18_COMPARISON.json',
#  '18_COMPARISON_1.json',
#  '18_COMPARISON_2.json',
#  '1_COMPARISON.json',
#  '1_COMPARISON_1.json',
#  '1_COMPARISON_2.json',
#  '21_COMPARISON.json',
#  '21_COMPARISON_1.json',
#  '21_COMPARISON_2.json',
#  '22_COMPARISON.json',
#  '22_COMPARISON_1.json',
#  '22_COMPARISON_2.json',
#  '23_COMPARISON.json',
#  '23_COMPARISON_1.json',
#  '23_COMPARISON_2.json',
#  '24_COMPARISON_1.json',
#  '24_COMPARISON_2.json',
#  '25_COMPARISON.json',
#  '2_COMPARISON.json',
#  '2_COMPARISON_1.json',
#  '2_COMPARISON_2.json',
#  '5_COMPARISON.json',
#  '5_COMPARISON_1.json',
#  '5_COMPARISON_2.json',
#  '6_COMPARISON.json',
#  '6_COMPARISON_1.json',
#  '6_COMPARISON_2.json',
#  '9_COMPARISON.json',
#  '9_COMPARISON_1.json',
#  '9_COMPARISON_2.json']

# %%
df = pd.DataFrame()

for file in files:
    with open("../Results/json_files/"+file) as json_file:
        json_data = json.load(json_file)
        df = pd.concat([df, pd.DataFrame(json_data)])

# %%
df
# Out:
#      Experiment_id Model Dataset  Learning rate  Noise level  Task size  \
# 0    10_COMPARISON  LSTM      HR           0.01         0.01         50
# 1    10_COMPARISON  LSTM      HR           0.01         0.01         50
# 2    10_COMPARISON  LSTM      HR           0.01         0.01         50
# 3    10_COMPARISON  LSTM      HR           0.01         0.01         50
# 4    10_COMPARISON  LSTM      HR           0.01         0.01         50
# ..             ...   ...     ...            ...          ...        ...
# 7   9_COMPARISON_2  LSTM      HR           0.01         0.01         50
# 8   9_COMPARISON_2  LSTM      HR           0.01         0.01         50
# 9   9_COMPARISON_2  LSTM      HR           0.01         0.01         50
# 10  9_COMPARISON_2  LSTM      HR           0.01         0.01         50
# 11  9_COMPARISON_2  LSTM      HR           0.01         0.01         50
#
#    Evaluation loss Vrae weight Training  ML-Horizon  Meta-learning rate  \
# 0         MAE Test           -     MAML           1              0.0005
# 1         MAE Test           -     MAML           1              0.0005
# 2         MAE Test           -     MAML           1              0.0005
# 3         MAE Test           -     MAML           1              0.0005
# 4         MAE Test           -     MAML           1              0.0005
# ..             ...         ...      ...         ...                 ...
# 7         MAE Test           -     MAML           1              0.0005
# 8         MAE Test           -     MAML           1              0.0005
# 9         MAE Test           -     MAML           1              0.0005
# 10        MAE Test           -     MAML           1              0.0005
# 11        MAE Test           -     MAML           1              0.0005
#
#     Trial  Adaptation steps  Horizon     Value  Val error  Final_epoch
# 0       0                 5       10  0.065904   0.059001         2161
# 1       0                 0       10  0.066002   0.090225         2161
# 2       0                 5        1  0.049037        NaN         2161
# 3       0                 0        1  0.064593        NaN         2161
# 4       1                 5       10  0.068092   0.060019         1370
# ..    ...               ...      ...       ...        ...          ...
# 7       1                 0        1  0.073234        NaN         1624
# 8       2                 1       10  0.078747   0.065613         1017
# 9       2                 0       10  0.068681   0.092993         1017
# 10      2                 1        1  0.062278        NaN         1017
# 11      2                 0        1  0.066639        NaN         1017
#
# [664 rows x 17 columns]

# %%
df.groupby(["Experiment_id", "Dataset", "Training","Adaptation steps", "Horizon", "Vrae weight"])["Value", "Val error"].agg(["mean", "std"])
# Out:
# C:\Users\Sebastian\Anaconda3\envs\pytorch12\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                                                           Value  \
#                                                                            mean
# Experiment_id   Dataset Training Adaptation steps Horizon Vrae weight
# 10_COMPARISON   HR      MAML     0                1       -            0.066833
#                                                   10      -            0.068432
#                                  5                1       -            0.050333
#                                                   10      -            0.067162
# 10_COMPARISON_1 HR      MAML     0                1       -            0.072844
# ...                                                                         ...
# 9_COMPARISON_1  HR      MAML     1                10      -            0.077721
# 9_COMPARISON_2  HR      MAML     0                1       -            0.070033
#                                                   10      -            0.071821
#                                  1                1       -            0.062970
#                                                   10      -            0.078993
#
#                                                                                  \
#                                                                             std
# Experiment_id   Dataset Training Adaptation steps Horizon Vrae weight
# 10_COMPARISON   HR      MAML     0                1       -            0.005355
#                                                   10      -            0.005505
#                                  5                1       -            0.001205
#                                                   10      -            0.001130
# 10_COMPARISON_1 HR      MAML     0                1       -            0.008459
# ...                                                                         ...
# 9_COMPARISON_1  HR      MAML     1                10      -            0.005297
# 9_COMPARISON_2  HR      MAML     0                1       -            0.003302
#                                                   10      -            0.003299
#                                  1                1       -            0.002589
#                                                   10      -            0.002376
#
#                                                                       Val error  \
#                                                                            mean
# Experiment_id   Dataset Training Adaptation steps Horizon Vrae weight
# 10_COMPARISON   HR      MAML     0                1       -                 NaN
#                                                   10      -            0.088727
#                                  5                1       -                 NaN
#                                                   10      -            0.059709
# 10_COMPARISON_1 HR      MAML     0                1       -                 NaN
# ...                                                                         ...
# 9_COMPARISON_1  HR      MAML     1                10      -            0.068214
# 9_COMPARISON_2  HR      MAML     0                1       -                 NaN
#                                                   10      -            0.090668
#                                  1                1       -                 NaN
#                                                   10      -            0.066779
#
#
#                                                                             std
# Experiment_id   Dataset Training Adaptation steps Horizon Vrae weight
# 10_COMPARISON   HR      MAML     0                1       -                 NaN
#                                                   10      -            0.001484
#                                  5                1       -                 NaN
#                                                   10      -            0.000614
# 10_COMPARISON_1 HR      MAML     0                1       -                 NaN
# ...                                                                         ...
# 9_COMPARISON_1  HR      MAML     1                10      -            0.002338
# 9_COMPARISON_2  HR      MAML     0                1       -                 NaN
#                                                   10      -            0.002053
#                                  1                1       -                 NaN
#                                                   10      -            0.001425
#
# [168 rows x 4 columns]

# %%
### horizon = 1
adaptation_steps = 1
dataset = "BATTERY"
experiment_type = "NOISE"
df2 = df[df["Dataset"]==dataset]
df2 = df2[(df2['Experiment_id'].str.contains("COMPARISON") )].groupby(["Experiment_id","Dataset", "Training", "Adaptation steps", "Horizon", "Learning rate", "Task size"])["Value", "Val error", "Final_epoch"].agg(["mean", "std", "count"])
df2
# Out:
# C:\Users\Sebastian\Anaconda3\envs\pytorch12\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                                                       Value  \
#                                                                                        mean
# Experiment_id   Dataset Training Adaptation steps Horizon Learning rate Task size
# 17_COMPARISON   BATTERY MAML     0                1       0.0001        50         0.002870
#                                                   10      0.0001        50         0.002098
#                                  1                1       0.0001        50         0.002441
#                                                   10      0.0001        50         0.001724
# 17_COMPARISON_1 BATTERY MAML     0                1       0.0001        50         0.002839
#                                                   10      0.0001        50         0.002053
#                                  1                1       0.0001        50         0.002431
#                                                   10      0.0001        50         0.001688
# 17_COMPARISON_2 BATTERY MAML     0                1       0.0010        50         0.005304
#                                                   10      0.0010        50         0.004892
#                                  1                1       0.0010        50         0.002395
#                                                   10      0.0010        50         0.002064
# 18_COMPARISON   BATTERY MAML     0                1       0.0001        50         0.003154
#                                                   10      0.0001        50         0.002401
#                                  5                1       0.0001        50         0.001642
#                                                   10      0.0001        50         0.001128
# 18_COMPARISON_1 BATTERY MAML     0                1       0.0001        50         0.003628
#                                                   10      0.0001        50         0.003037
#                                  10               1       0.0001        50         0.001345
#                                                   10      0.0001        50         0.001154
# 18_COMPARISON_2 BATTERY MAML     0                1       0.0010        50         0.035599
#                                                   10      0.0010        50         0.035840
#                                  10               1       0.0010        50         0.002789
#                                                   10      0.0010        50         0.002721
# 21_COMPARISON   BATTERY MMAML    0                1       0.0001        50         0.002419
#                                                   10      0.0001        50         0.001814
#                                  1                1       0.0001        50         0.002067
#                                                   10      0.0001        50         0.001541
# 21_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50         0.002849
#                                                   10      0.0001        50         0.002295
#                                  1                1       0.0001        50         0.002471
#                                                   10      0.0001        50         0.002059
# 21_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50         0.005797
#                                                   10      0.0010        50         0.004928
#                                  1                1       0.0010        50         0.002591
#                                                   10      0.0010        50         0.002853
# 22_COMPARISON   BATTERY MMAML    0                1       0.0001        50         0.005135
#                                                   10      0.0001        50         0.003922
#                                  10               1       0.0001        50         0.001932
#                                                   10      0.0001        50         0.002194
# 22_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50         0.004335
#                                                   10      0.0001        50         0.003333
#                                  10               1       0.0001        50         0.001690
#                                                   10      0.0001        50         0.001753
# 22_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50         0.037450
#                                                   10      0.0010        50         0.035486
#                                  10               1       0.0010        50         0.003021
#                                                   10      0.0010        50         0.003083
# 25_COMPARISON   BATTERY MMAML    0                1       0.0001        500        0.867584
#                                                   10      0.0001        500        0.867584
#                                  1                1       0.0001        500        0.867414
#                                                   10      0.0001        500        0.862781
#
#                                                                                              \
#                                                                                         std
# Experiment_id   Dataset Training Adaptation steps Horizon Learning rate Task size
# 17_COMPARISON   BATTERY MAML     0                1       0.0001        50         0.000053
#                                                   10      0.0001        50         0.000018
#                                  1                1       0.0001        50         0.000058
#                                                   10      0.0001        50         0.000076
# 17_COMPARISON_1 BATTERY MAML     0                1       0.0001        50         0.000133
#                                                   10      0.0001        50         0.000096
#                                  1                1       0.0001        50         0.000178
#                                                   10      0.0001        50         0.000146
# 17_COMPARISON_2 BATTERY MAML     0                1       0.0010        50         0.000786
#                                                   10      0.0010        50         0.000731
#                                  1                1       0.0010        50         0.000156
#                                                   10      0.0010        50         0.000161
# 18_COMPARISON   BATTERY MAML     0                1       0.0001        50         0.000035
#                                                   10      0.0001        50         0.000091
#                                  5                1       0.0001        50         0.000048
#                                                   10      0.0001        50         0.000019
# 18_COMPARISON_1 BATTERY MAML     0                1       0.0001        50         0.000130
#                                                   10      0.0001        50         0.000141
#                                  10               1       0.0001        50         0.000067
#                                                   10      0.0001        50         0.000042
# 18_COMPARISON_2 BATTERY MAML     0                1       0.0010        50         0.004543
#                                                   10      0.0010        50         0.004737
#                                  10               1       0.0010        50         0.000323
#                                                   10      0.0010        50         0.000251
# 21_COMPARISON   BATTERY MMAML    0                1       0.0001        50         0.000262
#                                                   10      0.0001        50         0.000216
#                                  1                1       0.0001        50         0.000247
#                                                   10      0.0001        50         0.000227
# 21_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50         0.000549
#                                                   10      0.0001        50         0.000659
#                                  1                1       0.0001        50         0.000543
#                                                   10      0.0001        50         0.000722
# 21_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50         0.001294
#                                                   10      0.0010        50         0.000805
#                                  1                1       0.0010        50         0.000280
#                                                   10      0.0010        50         0.000996
# 22_COMPARISON   BATTERY MMAML    0                1       0.0001        50         0.000206
#                                                   10      0.0001        50         0.000083
#                                  10               1       0.0001        50         0.000248
#                                                   10      0.0001        50         0.000259
# 22_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50         0.000813
#                                                   10      0.0001        50         0.000527
#                                  10               1       0.0001        50         0.000380
#                                                   10      0.0001        50         0.000663
# 22_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50         0.016467
#                                                   10      0.0010        50         0.015227
#                                  10               1       0.0010        50         0.000319
#                                                   10      0.0010        50         0.000463
# 25_COMPARISON   BATTERY MMAML    0                1       0.0001        500        0.039461
#                                                   10      0.0001        500        0.039461
#                                  1                1       0.0001        500        0.039458
#                                                   10      0.0001        500        0.040442
#
#                                                                                          \
#                                                                                   count
# Experiment_id   Dataset Training Adaptation steps Horizon Learning rate Task size
# 17_COMPARISON   BATTERY MAML     0                1       0.0001        50            3
#                                                   10      0.0001        50            3
#                                  1                1       0.0001        50            3
#                                                   10      0.0001        50            3
# 17_COMPARISON_1 BATTERY MAML     0                1       0.0001        50            5
#                                                   10      0.0001        50            5
#                                  1                1       0.0001        50            5
#                                                   10      0.0001        50            5
# 17_COMPARISON_2 BATTERY MAML     0                1       0.0010        50            5
#                                                   10      0.0010        50            5
#                                  1                1       0.0010        50            5
#                                                   10      0.0010        50            5
# 18_COMPARISON   BATTERY MAML     0                1       0.0001        50            3
#                                                   10      0.0001        50            3
#                                  5                1       0.0001        50            3
#                                                   10      0.0001        50            3
# 18_COMPARISON_1 BATTERY MAML     0                1       0.0001        50            5
#                                                   10      0.0001        50            5
#                                  10               1       0.0001        50            5
#                                                   10      0.0001        50            5
# 18_COMPARISON_2 BATTERY MAML     0                1       0.0010        50            5
#                                                   10      0.0010        50            5
#                                  10               1       0.0010        50            5
#                                                   10      0.0010        50            5
# 21_COMPARISON   BATTERY MMAML    0                1       0.0001        50            3
#                                                   10      0.0001        50            3
#                                  1                1       0.0001        50            3
#                                                   10      0.0001        50            3
# 21_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50            5
#                                                   10      0.0001        50            5
#                                  1                1       0.0001        50            5
#                                                   10      0.0001        50            5
# 21_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50            5
#                                                   10      0.0010        50            5
#                                  1                1       0.0010        50            5
#                                                   10      0.0010        50            5
# 22_COMPARISON   BATTERY MMAML    0                1       0.0001        50            3
#                                                   10      0.0001        50            3
#                                  10               1       0.0001        50            3
#                                                   10      0.0001        50            3
# 22_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50            5
#                                                   10      0.0001        50            5
#                                  10               1       0.0001        50            5
#                                                   10      0.0001        50            5
# 22_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50            5
#                                                   10      0.0010        50            5
#                                  10               1       0.0010        50            5
#                                                   10      0.0010        50            5
# 25_COMPARISON   BATTERY MMAML    0                1       0.0001        500           3
#                                                   10      0.0001        500           3
#                                  1                1       0.0001        500           3
#                                                   10      0.0001        500           3
#
#                                                                                   Val error  \
#                                                                                        mean
# Experiment_id   Dataset Training Adaptation steps Horizon Learning rate Task size
# 17_COMPARISON   BATTERY MAML     0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.002333
#                                  1                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.001989
# 17_COMPARISON_1 BATTERY MAML     0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.002301
#                                  1                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.001954
# 17_COMPARISON_2 BATTERY MAML     0                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.005091
#                                  1                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.002254
# 18_COMPARISON   BATTERY MAML     0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.002656
#                                  5                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.001413
# 18_COMPARISON_1 BATTERY MAML     0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.003213
#                                  10               1       0.0001        50              NaN
#                                                   10      0.0001        50         0.001323
# 18_COMPARISON_2 BATTERY MAML     0                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.035198
#                                  10               1       0.0010        50              NaN
#                                                   10      0.0010        50         0.002729
# 21_COMPARISON   BATTERY MMAML    0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.002083
#                                  1                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.001846
# 21_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.002537
#                                  1                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.002302
# 21_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.005026
#                                  1                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.003072
# 22_COMPARISON   BATTERY MMAML    0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.003816
#                                  10               1       0.0001        50              NaN
#                                                   10      0.0001        50         0.002374
# 22_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.003519
#                                  10               1       0.0001        50              NaN
#                                                   10      0.0001        50         0.001953
# 22_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.035133
#                                  10               1       0.0010        50              NaN
#                                                   10      0.0010        50         0.003213
# 25_COMPARISON   BATTERY MMAML    0                1       0.0001        500             NaN
#                                                   10      0.0001        500        0.868844
#                                  1                1       0.0001        500             NaN
#                                                   10      0.0001        500        0.863306
#
#                                                                                              \
#                                                                                         std
# Experiment_id   Dataset Training Adaptation steps Horizon Learning rate Task size
# 17_COMPARISON   BATTERY MAML     0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000032
#                                  1                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000025
# 17_COMPARISON_1 BATTERY MAML     0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000100
#                                  1                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000150
# 17_COMPARISON_2 BATTERY MAML     0                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.000562
#                                  1                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.000118
# 18_COMPARISON   BATTERY MAML     0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000081
#                                  5                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000016
# 18_COMPARISON_1 BATTERY MAML     0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000141
#                                  10               1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000044
# 18_COMPARISON_2 BATTERY MAML     0                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.004946
#                                  10               1       0.0010        50              NaN
#                                                   10      0.0010        50         0.000142
# 21_COMPARISON   BATTERY MMAML    0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000254
#                                  1                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000253
# 21_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000674
#                                  1                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000747
# 21_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.000863
#                                  1                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.001081
# 22_COMPARISON   BATTERY MMAML    0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000085
#                                  10               1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000280
# 22_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000416
#                                  10               1       0.0001        50              NaN
#                                                   10      0.0001        50         0.000699
# 22_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50              NaN
#                                                   10      0.0010        50         0.015120
#                                  10               1       0.0010        50              NaN
#                                                   10      0.0010        50         0.000597
# 25_COMPARISON   BATTERY MMAML    0                1       0.0001        500             NaN
#                                                   10      0.0001        500        0.039167
#                                  1                1       0.0001        500             NaN
#                                                   10      0.0001        500        0.040466
#
#                                                                                          \
#                                                                                   count
# Experiment_id   Dataset Training Adaptation steps Horizon Learning rate Task size
# 17_COMPARISON   BATTERY MAML     0                1       0.0001        50            0
#                                                   10      0.0001        50            3
#                                  1                1       0.0001        50            0
#                                                   10      0.0001        50            3
# 17_COMPARISON_1 BATTERY MAML     0                1       0.0001        50            0
#                                                   10      0.0001        50            5
#                                  1                1       0.0001        50            0
#                                                   10      0.0001        50            5
# 17_COMPARISON_2 BATTERY MAML     0                1       0.0010        50            0
#                                                   10      0.0010        50            5
#                                  1                1       0.0010        50            0
#                                                   10      0.0010        50            5
# 18_COMPARISON   BATTERY MAML     0                1       0.0001        50            0
#                                                   10      0.0001        50            3
#                                  5                1       0.0001        50            0
#                                                   10      0.0001        50            3
# 18_COMPARISON_1 BATTERY MAML     0                1       0.0001        50            0
#                                                   10      0.0001        50            5
#                                  10               1       0.0001        50            0
#                                                   10      0.0001        50            5
# 18_COMPARISON_2 BATTERY MAML     0                1       0.0010        50            0
#                                                   10      0.0010        50            5
#                                  10               1       0.0010        50            0
#                                                   10      0.0010        50            5
# 21_COMPARISON   BATTERY MMAML    0                1       0.0001        50            0
#                                                   10      0.0001        50            3
#                                  1                1       0.0001        50            0
#                                                   10      0.0001        50            3
# 21_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50            0
#                                                   10      0.0001        50            5
#                                  1                1       0.0001        50            0
#                                                   10      0.0001        50            5
# 21_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50            0
#                                                   10      0.0010        50            5
#                                  1                1       0.0010        50            0
#                                                   10      0.0010        50            5
# 22_COMPARISON   BATTERY MMAML    0                1       0.0001        50            0
#                                                   10      0.0001        50            3
#                                  10               1       0.0001        50            0
#                                                   10      0.0001        50            3
# 22_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50            0
#                                                   10      0.0001        50            5
#                                  10               1       0.0001        50            0
#                                                   10      0.0001        50            5
# 22_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50            0
#                                                   10      0.0010        50            5
#                                  10               1       0.0010        50            0
#                                                   10      0.0010        50            5
# 25_COMPARISON   BATTERY MMAML    0                1       0.0001        500           0
#                                                   10      0.0001        500           3
#                                  1                1       0.0001        500           0
#                                                   10      0.0001        500           3
#
#                                                                                    Final_epoch  \
#                                                                                           mean
# Experiment_id   Dataset Training Adaptation steps Horizon Learning rate Task size
# 17_COMPARISON   BATTERY MAML     0                1       0.0001        50         2566.666667
#                                                   10      0.0001        50         2566.666667
#                                  1                1       0.0001        50         2566.666667
#                                                   10      0.0001        50         2566.666667
# 17_COMPARISON_1 BATTERY MAML     0                1       0.0001        50         2886.000000
#                                                   10      0.0001        50         2886.000000
#                                  1                1       0.0001        50         2886.000000
#                                                   10      0.0001        50         2886.000000
# 17_COMPARISON_2 BATTERY MAML     0                1       0.0010        50         1541.200000
#                                                   10      0.0010        50         1541.200000
#                                  1                1       0.0010        50         1541.200000
#                                                   10      0.0010        50         1541.200000
# 18_COMPARISON   BATTERY MAML     0                1       0.0001        50         2137.000000
#                                                   10      0.0001        50         2137.000000
#                                  5                1       0.0001        50         2137.000000
#                                                   10      0.0001        50         2137.000000
# 18_COMPARISON_1 BATTERY MAML     0                1       0.0001        50         2064.000000
#                                                   10      0.0001        50         2064.000000
#                                  10               1       0.0001        50         2064.000000
#                                                   10      0.0001        50         2064.000000
# 18_COMPARISON_2 BATTERY MAML     0                1       0.0010        50         1333.200000
#                                                   10      0.0010        50         1333.200000
#                                  10               1       0.0010        50         1333.200000
#                                                   10      0.0010        50         1333.200000
# 21_COMPARISON   BATTERY MMAML    0                1       0.0001        50         3303.666667
#                                                   10      0.0001        50         3303.666667
#                                  1                1       0.0001        50         3303.666667
#                                                   10      0.0001        50         3303.666667
# 21_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50         2566.800000
#                                                   10      0.0001        50         2566.800000
#                                  1                1       0.0001        50         2566.800000
#                                                   10      0.0001        50         2566.800000
# 21_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50         1844.600000
#                                                   10      0.0010        50         1844.600000
#                                  1                1       0.0010        50         1844.600000
#                                                   10      0.0010        50         1844.600000
# 22_COMPARISON   BATTERY MMAML    0                1       0.0001        50         1408.666667
#                                                   10      0.0001        50         1408.666667
#                                  10               1       0.0001        50         1408.666667
#                                                   10      0.0001        50         1408.666667
# 22_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50         1966.600000
#                                                   10      0.0001        50         1966.600000
#                                  10               1       0.0001        50         1966.600000
#                                                   10      0.0001        50         1966.600000
# 22_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50         1889.400000
#                                                   10      0.0010        50         1889.400000
#                                  10               1       0.0010        50         1889.400000
#                                                   10      0.0010        50         1889.400000
# 25_COMPARISON   BATTERY MMAML    0                1       0.0001        500           1.000000
#                                                   10      0.0001        500           1.000000
#                                  1                1       0.0001        500           1.000000
#                                                   10      0.0001        500           1.000000
#
#                                                                                                 \
#                                                                                            std
# Experiment_id   Dataset Training Adaptation steps Horizon Learning rate Task size
# 17_COMPARISON   BATTERY MAML     0                1       0.0001        50          141.803855
#                                                   10      0.0001        50          141.803855
#                                  1                1       0.0001        50          141.803855
#                                                   10      0.0001        50          141.803855
# 17_COMPARISON_1 BATTERY MAML     0                1       0.0001        50         1471.508919
#                                                   10      0.0001        50         1471.508919
#                                  1                1       0.0001        50         1471.508919
#                                                   10      0.0001        50         1471.508919
# 17_COMPARISON_2 BATTERY MAML     0                1       0.0010        50          373.077338
#                                                   10      0.0010        50          373.077338
#                                  1                1       0.0010        50          373.077338
#                                                   10      0.0010        50          373.077338
# 18_COMPARISON   BATTERY MAML     0                1       0.0001        50          143.164241
#                                                   10      0.0001        50          143.164241
#                                  5                1       0.0001        50          143.164241
#                                                   10      0.0001        50          143.164241
# 18_COMPARISON_1 BATTERY MAML     0                1       0.0001        50          742.258378
#                                                   10      0.0001        50          742.258378
#                                  10               1       0.0001        50          742.258378
#                                                   10      0.0001        50          742.258378
# 18_COMPARISON_2 BATTERY MAML     0                1       0.0010        50          497.305439
#                                                   10      0.0010        50          497.305439
#                                  10               1       0.0010        50          497.305439
#                                                   10      0.0010        50          497.305439
# 21_COMPARISON   BATTERY MMAML    0                1       0.0001        50         1420.555290
#                                                   10      0.0001        50         1420.555290
#                                  1                1       0.0001        50         1420.555290
#                                                   10      0.0001        50         1420.555290
# 21_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50         1071.072220
#                                                   10      0.0001        50         1071.072220
#                                  1                1       0.0001        50         1071.072220
#                                                   10      0.0001        50         1071.072220
# 21_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50          646.000232
#                                                   10      0.0010        50          646.000232
#                                  1                1       0.0010        50          646.000232
#                                                   10      0.0010        50          646.000232
# 22_COMPARISON   BATTERY MMAML    0                1       0.0001        50          151.414442
#                                                   10      0.0001        50          151.414442
#                                  10               1       0.0001        50          151.414442
#                                                   10      0.0001        50          151.414442
# 22_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50          762.902549
#                                                   10      0.0001        50          762.902549
#                                  10               1       0.0001        50          762.902549
#                                                   10      0.0001        50          762.902549
# 22_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50          901.985199
#                                                   10      0.0010        50          901.985199
#                                  10               1       0.0010        50          901.985199
#                                                   10      0.0010        50          901.985199
# 25_COMPARISON   BATTERY MMAML    0                1       0.0001        500           0.000000
#                                                   10      0.0001        500           0.000000
#                                  1                1       0.0001        500           0.000000
#                                                   10      0.0001        500           0.000000
#
#
#                                                                                   count
# Experiment_id   Dataset Training Adaptation steps Horizon Learning rate Task size
# 17_COMPARISON   BATTERY MAML     0                1       0.0001        50            3
#                                                   10      0.0001        50            3
#                                  1                1       0.0001        50            3
#                                                   10      0.0001        50            3
# 17_COMPARISON_1 BATTERY MAML     0                1       0.0001        50            5
#                                                   10      0.0001        50            5
#                                  1                1       0.0001        50            5
#                                                   10      0.0001        50            5
# 17_COMPARISON_2 BATTERY MAML     0                1       0.0010        50            5
#                                                   10      0.0010        50            5
#                                  1                1       0.0010        50            5
#                                                   10      0.0010        50            5
# 18_COMPARISON   BATTERY MAML     0                1       0.0001        50            3
#                                                   10      0.0001        50            3
#                                  5                1       0.0001        50            3
#                                                   10      0.0001        50            3
# 18_COMPARISON_1 BATTERY MAML     0                1       0.0001        50            5
#                                                   10      0.0001        50            5
#                                  10               1       0.0001        50            5
#                                                   10      0.0001        50            5
# 18_COMPARISON_2 BATTERY MAML     0                1       0.0010        50            5
#                                                   10      0.0010        50            5
#                                  10               1       0.0010        50            5
#                                                   10      0.0010        50            5
# 21_COMPARISON   BATTERY MMAML    0                1       0.0001        50            3
#                                                   10      0.0001        50            3
#                                  1                1       0.0001        50            3
#                                                   10      0.0001        50            3
# 21_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50            5
#                                                   10      0.0001        50            5
#                                  1                1       0.0001        50            5
#                                                   10      0.0001        50            5
# 21_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50            5
#                                                   10      0.0010        50            5
#                                  1                1       0.0010        50            5
#                                                   10      0.0010        50            5
# 22_COMPARISON   BATTERY MMAML    0                1       0.0001        50            3
#                                                   10      0.0001        50            3
#                                  10               1       0.0001        50            3
#                                                   10      0.0001        50            3
# 22_COMPARISON_1 BATTERY MMAML    0                1       0.0001        50            5
#                                                   10      0.0001        50            5
#                                  10               1       0.0001        50            5
#                                                   10      0.0001        50            5
# 22_COMPARISON_2 BATTERY MMAML    0                1       0.0010        50            5
#                                                   10      0.0010        50            5
#                                  10               1       0.0010        50            5
#                                                   10      0.0010        50            5
# 25_COMPARISON   BATTERY MMAML    0                1       0.0001        500           3
#                                                   10      0.0001        500           3
#                                  1                1       0.0001        500           3
#                                                   10      0.0001        500           3

# %%
# horizon = 1
adaptation_steps = 1
dataset = "HR"
experiment_type = "NOISE"
df2 = df[df["Dataset"]==dataset]
df2 = df2[(df2['Experiment_id'].str.contains("COMPARISON") )].groupby(["Dataset", "Training", "Adaptation steps", "Horizon", "Learning rate", "Task size", "Vrae weight"])["Value", "Val error", "Final_epoch"].agg(["mean", "std", "count"])
df2
# Out:
# C:\Users\Sebastian\Anaconda3\envs\pytorch12\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                                                                   Value  \
#                                                                                    mean
# Dataset Training Adaptation steps Horizon Learning rate Task size Vrae weight
# HR      MAML     0                1       0.01          50        -            0.070878
#                                   10      0.01          50        -            0.071907
#                  1                1       0.01          50        -            0.063284
#                                   10      0.01          50        -            0.079158
#                  5                1       0.01          50        -            0.050333
#                                   10      0.01          50        -            0.067162
#                  10               1       0.01          50        -            0.051161
#                                   10      0.01          50        -            0.071135
#         MMAML    0                1       0.01          50        0.01         0.088667
#                                                         500       0.01         0.086665
#                                   10      0.01          50        0.01         0.102677
#                                                         500       0.01         0.086344
#                  1                1       0.01          50        0.01         0.045401
#                                                         500       0.01         0.075880
#                                   10      0.01          50        0.01         0.069039
#                                                         500       0.01         0.080364
#                  5                1       0.01          50        0.01         0.047031
#                                   10      0.01          50        0.01         0.068849
#                  10               1       0.01          50        0.01         0.050513
#                                   10      0.01          50        0.01         0.072074
#
#                                                                                          \
#                                                                                     std
# Dataset Training Adaptation steps Horizon Learning rate Task size Vrae weight
# HR      MAML     0                1       0.01          50        -            0.005787
#                                   10      0.01          50        -            0.005271
#                  1                1       0.01          50        -            0.002327
#                                   10      0.01          50        -            0.003292
#                  5                1       0.01          50        -            0.001205
#                                   10      0.01          50        -            0.001130
#                  10               1       0.01          50        -            0.002977
#                                   10      0.01          50        -            0.009046
#         MMAML    0                1       0.01          50        0.01         0.041926
#                                                         500       0.01         0.011509
#                                   10      0.01          50        0.01         0.036210
#                                                         500       0.01         0.009431
#                  1                1       0.01          50        0.01         0.002358
#                                                         500       0.01         0.011710
#                                   10      0.01          50        0.01         0.003157
#                                                         500       0.01         0.007396
#                  5                1       0.01          50        0.01         0.001953
#                                   10      0.01          50        0.01         0.003997
#                  10               1       0.01          50        0.01         0.001130
#                                   10      0.01          50        0.01         0.003104
#
#                                                                                      \
#                                                                               count
# Dataset Training Adaptation steps Horizon Learning rate Task size Vrae weight
# HR      MAML     0                1       0.01          50        -              18
#                                   10      0.01          50        -              18
#                  1                1       0.01          50        -               9
#                                   10      0.01          50        -               9
#                  5                1       0.01          50        -               3
#                                   10      0.01          50        -               3
#                  10               1       0.01          50        -               6
#                                   10      0.01          50        -               6
#         MMAML    0                1       0.01          50        0.01           26
#                                                         500       0.01           10
#                                   10      0.01          50        0.01           26
#                                                         500       0.01           10
#                  1                1       0.01          50        0.01           13
#                                                         500       0.01           10
#                                   10      0.01          50        0.01           13
#                                                         500       0.01           10
#                  5                1       0.01          50        0.01            3
#                                   10      0.01          50        0.01            3
#                  10               1       0.01          50        0.01           10
#                                   10      0.01          50        0.01           10
#
#                                                                               Val error  \
#                                                                                    mean
# Dataset Training Adaptation steps Horizon Learning rate Task size Vrae weight
# HR      MAML     0                1       0.01          50        -                 NaN
#                                   10      0.01          50        -            0.091944
#                  1                1       0.01          50        -                 NaN
#                                   10      0.01          50        -            0.067359
#                  5                1       0.01          50        -                 NaN
#                                   10      0.01          50        -            0.059709
#                  10               1       0.01          50        -                 NaN
#                                   10      0.01          50        -            0.061365
#         MMAML    0                1       0.01          50        0.01              NaN
#                                                         500       0.01              NaN
#                                   10      0.01          50        0.01         0.096782
#                                                         500       0.01         0.089141
#                  1                1       0.01          50        0.01              NaN
#                                                         500       0.01              NaN
#                                   10      0.01          50        0.01         0.064952
#                                                         500       0.01         0.082360
#                  5                1       0.01          50        0.01              NaN
#                                   10      0.01          50        0.01         0.064989
#                  10               1       0.01          50        0.01              NaN
#                                   10      0.01          50        0.01         0.064592
#
#                                                                                          \
#                                                                                     std
# Dataset Training Adaptation steps Horizon Learning rate Task size Vrae weight
# HR      MAML     0                1       0.01          50        -                 NaN
#                                   10      0.01          50        -            0.004444
#                  1                1       0.01          50        -                 NaN
#                                   10      0.01          50        -            0.001562
#                  5                1       0.01          50        -                 NaN
#                                   10      0.01          50        -            0.000614
#                  10               1       0.01          50        -                 NaN
#                                   10      0.01          50        -            0.005169
#         MMAML    0                1       0.01          50        0.01              NaN
#                                                         500       0.01              NaN
#                                   10      0.01          50        0.01         0.029368
#                                                         500       0.01         0.009158
#                  1                1       0.01          50        0.01              NaN
#                                                         500       0.01              NaN
#                                   10      0.01          50        0.01         0.001437
#                                                         500       0.01         0.002638
#                  5                1       0.01          50        0.01              NaN
#                                   10      0.01          50        0.01         0.002337
#                  10               1       0.01          50        0.01              NaN
#                                   10      0.01          50        0.01         0.001344
#
#                                                                                      \
#                                                                               count
# Dataset Training Adaptation steps Horizon Learning rate Task size Vrae weight
# HR      MAML     0                1       0.01          50        -               0
#                                   10      0.01          50        -              18
#                  1                1       0.01          50        -               0
#                                   10      0.01          50        -               9
#                  5                1       0.01          50        -               0
#                                   10      0.01          50        -               3
#                  10               1       0.01          50        -               0
#                                   10      0.01          50        -               6
#         MMAML    0                1       0.01          50        0.01            0
#                                                         500       0.01            0
#                                   10      0.01          50        0.01           26
#                                                         500       0.01           10
#                  1                1       0.01          50        0.01            0
#                                                         500       0.01            0
#                                   10      0.01          50        0.01           13
#                                                         500       0.01           10
#                  5                1       0.01          50        0.01            0
#                                   10      0.01          50        0.01            3
#                  10               1       0.01          50        0.01            0
#                                   10      0.01          50        0.01           10
#
#                                                                                Final_epoch  \
#                                                                                       mean
# Dataset Training Adaptation steps Horizon Learning rate Task size Vrae weight
# HR      MAML     0                1       0.01          50        -            1430.111111
#                                   10      0.01          50        -            1430.111111
#                  1                1       0.01          50        -            1198.666667
#                                   10      0.01          50        -            1198.666667
#                  5                1       0.01          50        -            1717.666667
#                                   10      0.01          50        -            1717.666667
#                  10               1       0.01          50        -            1633.500000
#                                   10      0.01          50        -            1633.500000
#         MMAML    0                1       0.01          50        0.01         1542.307692
#                                                         500       0.01          615.200000
#                                   10      0.01          50        0.01         1542.307692
#                                                         500       0.01          615.200000
#                  1                1       0.01          50        0.01         1565.000000
#                                                         500       0.01          615.200000
#                                   10      0.01          50        0.01         1565.000000
#                                                         500       0.01          615.200000
#                  5                1       0.01          50        0.01         1425.333333
#                                   10      0.01          50        0.01         1425.333333
#                  10               1       0.01          50        0.01         1547.900000
#                                   10      0.01          50        0.01         1547.900000
#
#                                                                                            \
#                                                                                       std
# Dataset Training Adaptation steps Horizon Learning rate Task size Vrae weight
# HR      MAML     0                1       0.01          50        -            493.617009
#                                   10      0.01          50        -            493.617009
#                  1                1       0.01          50        -            368.923434
#                                   10      0.01          50        -            368.923434
#                  5                1       0.01          50        -            404.084562
#                                   10      0.01          50        -            404.084562
#                  10               1       0.01          50        -            591.339412
#                                   10      0.01          50        -            591.339412
#         MMAML    0                1       0.01          50        0.01         312.834368
#                                                         500       0.01         128.562825
#                                   10      0.01          50        0.01         312.834368
#                                                         500       0.01         128.562825
#                  1                1       0.01          50        0.01         335.748914
#                                                         500       0.01         128.562825
#                                   10      0.01          50        0.01         335.748914
#                                                         500       0.01         128.562825
#                  5                1       0.01          50        0.01         353.921366
#                                   10      0.01          50        0.01         353.921366
#                  10               1       0.01          50        0.01         297.270715
#                                   10      0.01          50        0.01         297.270715
#
#
#                                                                               count
# Dataset Training Adaptation steps Horizon Learning rate Task size Vrae weight
# HR      MAML     0                1       0.01          50        -              18
#                                   10      0.01          50        -              18
#                  1                1       0.01          50        -               9
#                                   10      0.01          50        -               9
#                  5                1       0.01          50        -               3
#                                   10      0.01          50        -               3
#                  10               1       0.01          50        -               6
#                                   10      0.01          50        -               6
#         MMAML    0                1       0.01          50        0.01           26
#                                                         500       0.01           10
#                                   10      0.01          50        0.01           26
#                                                         500       0.01           10
#                  1                1       0.01          50        0.01           13
#                                                         500       0.01           10
#                                   10      0.01          50        0.01           13
#                                                         500       0.01           10
#                  5                1       0.01          50        0.01            3
#                                   10      0.01          50        0.01            3
#                  10               1       0.01          50        0.01           10
#                                   10      0.01          50        0.01           10

# %%
df[(df['Experiment_id'].str.contains("COMPARISON") )& (df["Dataset"]=="POLLUTION") & (df["Training"]=="MMAML") & (df["Adaptation steps"]==1) & (df["Horizon"]==1) ][:5].groupby("Training").agg(["mean", "std"])
# Out:
#          Learning rate      Noise level      Task size      ML-Horizon       \
#                   mean  std        mean  std      mean  std       mean  std
# Training
# MMAML             0.01  0.0        0.01  0.0       500  0.0          1  0.0
#
#          Meta-learning rate       ... Adaptation steps      Horizon       \
#                        mean  std  ...             mean  std    mean  std
# Training                          ...
# MMAML                0.0005  0.0  ...                1  0.0       1  0.0
#
#              Value           Val error     Final_epoch
#               mean       std      mean std        mean       std
# Training
# MMAML     0.041756  0.001415       NaN NaN       518.2  9.093954
#
# [1 rows x 22 columns]

# %%
df[(df['Experiment_id'].str.contains("COMPARISON") )& (df["Dataset"]=="POLLUTION") & (df["Training"]=="MMAML") & (df["Adaptation steps"]==1) & (df["Horizon"]==10) & (df["Task size"]==500)  ][-5:].groupby("Training").agg(["mean", "std", "count"])
# Out:
#          Learning rate            Noise level            Task size             \
#                   mean  std count        mean  std count      mean  std count
# Training
# MMAML           0.0001  0.0     5        0.01  0.0     5       500  0.0     5
#
#          ML-Horizon  ... Horizon     Value                 Val error  \
#                mean  ...   count      mean       std count      mean
# Training             ...
# MMAML             1  ...       5  0.048065  0.002368     5  0.033837
#
#                          Final_epoch
#                std count        mean        std count
# Training
# MMAML     0.001723     5         519  13.838353     5
#
# [1 rows x 33 columns]

# %% [markdown]
# ##### Ablation

# %%
files = os.listdir("json_files/")
files = [file  for file in files if "ABLATION" in file ]

# %%
files
# Out:
# ['HORIZON1_ABLATION.json',
#  'HORIZON1_ABLATION_1.json',
#  'HORIZON2_ABLATION.json',
#  'HORIZON2_ABLATION_1.json',
#  'HORIZON3_ABLATION.json',
#  'HORIZON3_ABLATION_1.json',
#  'HORIZON4_ABLATION_1.json',
#  'HORIZON5_ABLATION.json',
#  'HORIZON5_ABLATION_1.json',
#  'HORIZON6_ABLATION_1.json',
#  'HORIZON7_ABLATION_1.json',
#  'HORIZON8_ABLATION_1.json',
#  'HORIZON9_ABLATION.json',
#  'HORIZON9_ABLATION_1.json',
#  'NOISE10_ABLATION.json',
#  'NOISE10_ABLATION_1.json',
#  'NOISE10_ABLATION_2.json',
#  'NOISE11_ABLATION.json',
#  'NOISE11_ABLATION_1.json',
#  'NOISE11_ABLATION_2.json',
#  'NOISE12_ABLATION.json',
#  'NOISE12_ABLATION_1.json',
#  'NOISE12_ABLATION_2.json',
#  'NOISE1_ABLATION.json',
#  'NOISE1_ABLATION_1.json',
#  'NOISE1_ABLATION_2.json',
#  'NOISE2_ABLATION.json',
#  'NOISE2_ABLATION_1.json',
#  'NOISE2_ABLATION_2.json',
#  'NOISE3_ABLATION.json',
#  'NOISE3_ABLATION_1.json',
#  'NOISE3_ABLATION_2.json',
#  'NOISE4_ABLATION.json',
#  'NOISE4_ABLATION_1.json',
#  'NOISE4_ABLATION_2.json',
#  'NOISE5_ABLATION.json',
#  'NOISE5_ABLATION_1.json',
#  'NOISE5_ABLATION_2.json',
#  'NOISE6_ABLATION.json',
#  'NOISE6_ABLATION_1.json',
#  'NOISE6_ABLATION_2.json',
#  'NOISE7_ABLATION.json',
#  'NOISE7_ABLATION_1.json',
#  'NOISE7_ABLATION_2.json',
#  'NOISE8_ABLATION.json',
#  'NOISE8_ABLATION_1.json',
#  'NOISE8_ABLATION_2.json',
#  'NOISE9_ABLATION.json',
#  'NOISE9_ABLATION_1.json',
#  'NOISE9_ABLATION_2.json',
#  'VRAE10_ABLATION.json',
#  'VRAE10_ABLATION_1.json',
#  'VRAE10_ABLATION_2.json',
#  'VRAE11_ABLATION.json',
#  'VRAE11_ABLATION_1.json',
#  'VRAE11_ABLATION_2.json',
#  'VRAE12_ABLATION.json',
#  'VRAE12_ABLATION_1.json',
#  'VRAE12_ABLATION_2.json',
#  'VRAE1_ABLATION.json',
#  'VRAE1_ABLATION_1.json',
#  'VRAE2_ABLATION.json',
#  'VRAE2_ABLATION_1.json',
#  'VRAE3_ABLATION.json',
#  'VRAE3_ABLATION_1.json',
#  'VRAE4_ABLATION.json',
#  'VRAE4_ABLATION_1.json',
#  'VRAE5_ABLATION.json',
#  'VRAE5_ABLATION_1.json',
#  'VRAE6_ABLATION.json',
#  'VRAE6_ABLATION_1.json',
#  'VRAE7_ABLATION.json',
#  'VRAE7_ABLATION_1.json',
#  'VRAE8_ABLATION.json',
#  'VRAE8_ABLATION_1.json',
#  'VRAE9_ABLATION.json',
#  'VRAE9_ABLATION_1.json',
#  'VRAE9_ABLATION_2.json']

# %%
df = pd.DataFrame()

for file in files:
    with open("../Results/json_files/"+file) as json_file:
        json_data = json.load(json_file)
        df = pd.concat([df, pd.DataFrame(json_data)])

# %%
df
# Out:
#         Experiment_id Model  Dataset  Learning rate  Noise level  Task size  \
# 0   HORIZON1_ABLATION  LSTM       HR          0.010          0.0         50
# 1   HORIZON1_ABLATION  LSTM       HR          0.010          0.0         50
# 2   HORIZON1_ABLATION  LSTM       HR          0.010          0.0         50
# 3   HORIZON1_ABLATION  LSTM       HR          0.010          0.0         50
# 4   HORIZON1_ABLATION  LSTM       HR          0.010          0.0         50
# ..                ...   ...      ...            ...          ...        ...
# 15   VRAE9_ABLATION_2  LSTM  BATTERY          0.001          0.0         50
# 16   VRAE9_ABLATION_2  LSTM  BATTERY          0.001          0.0         50
# 17   VRAE9_ABLATION_2  LSTM  BATTERY          0.001          0.0         50
# 18   VRAE9_ABLATION_2  LSTM  BATTERY          0.001          0.0         50
# 19   VRAE9_ABLATION_2  LSTM  BATTERY          0.001          0.0         50
#
#    Evaluation loss Vrae weight Training  Meta-learning rate  ML-Horizon  \
# 0         MAE Test           0    MMAML             0.00050           1
# 1         MAE Test           0    MMAML             0.00050           1
# 2         MAE Test           0    MMAML             0.00050           1
# 3         MAE Test           0    MMAML             0.00050           1
# 4         MAE Test           0    MMAML             0.00050           1
# ..             ...         ...      ...                 ...         ...
# 15        MAE Test         0.1    MMAML             0.00005           1
# 16        MAE Test         0.1    MMAML             0.00005           1
# 17        MAE Test         0.1    MMAML             0.00005           1
# 18        MAE Test         0.1    MMAML             0.00005           1
# 19        MAE Test         0.1    MMAML             0.00005           1
#
#     Trial  Adaptation steps  Horizon     Value  Val error  Final_epoch
# 0       0                 1       10  0.064623   0.064244         2128
# 1       0                 0       10  0.069046   0.071048         2128
# 2       0                 1        1  0.042141        NaN         2128
# 3       0                 0        1  0.050182        NaN         2128
# 4       1                 1       10  0.068950   0.062990         1745
# ..    ...               ...      ...       ...        ...          ...
# 15      3                 0        1  0.006964        NaN          883
# 16      4                 1       10  0.003313   0.003566         1680
# 17      4                 0       10  0.005427   0.005534         1680
# 18      4                 1        1  0.002955        NaN         1680
# 19      4                 0        1  0.007138        NaN         1680
#
# [1328 rows x 17 columns]

# %%
df1 = df.groupby(["Experiment_id", "Dataset", "ML-Horizon","Adaptation steps", "Horizon", "Vrae weight", "Noise level"])["Value", "Val error"].agg(["mean", "std"])
df1.to_csv("results_ablation.csv")
# Out:
# C:\Users\Sebastian\Anaconda3\envs\pytorch12\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Graph

# %%
dataset = "BATTERY"
experiment_type =  "VRAE"

# %%
df[df['Experiment_id'].str.contains("VRAE") & df.Dataset=="HR"]
# Out:
# C:\Users\Sebastian\Anaconda3\envs\pytorch12\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Empty DataFrame
# Columns: [Experiment_id, Model, Dataset, Learning rate, Noise level, Task size, Evaluation loss, Vrae weight, Training, Meta-learning rate, ML-Horizon, Trial, Adaptation steps, Horizon, Value, Val error, Final_epoch]
# Index: []

# %%
df2 = df[(df['Experiment_id'].str.contains("VRAE") ) & (df["Dataset"] == "HR")].groupby(["Vrae weight", "Adaptation steps", "Horizon", "Task size"])["Value", "Val error"].agg(["mean", "std"])
# Out:
# C:\Users\Sebastian\Anaconda3\envs\pytorch12\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
horizon = 10
adaptation_steps = 1
dataset = "POLLUTION"
experiment_type = "VRAE"
df2 = df[(df['Experiment_id'].str.contains(experiment_type) ) & (df["Dataset"] == dataset) & (df["Horizon"] == horizon) & (df["Adaptation steps"]== adaptation_steps)].groupby(["Vrae weight", "Adaptation steps", "Horizon", "Task size"])["Value"].agg(["mean"])

# %%
plt.plot(np.array(df2["mean"]))

# %%
horizon = 10
adaptation_steps = 1
dataset = "HR"
experiment_type = "VRAE"
df2 = df[(df['Experiment_id'].str.contains(experiment_type) ) & (df["Dataset"] == dataset) & (df["Horizon"] == horizon) & (df["Adaptation steps"]== adaptation_steps)].groupby(["Vrae weight", "Adaptation steps", "Horizon", "Task size"])["Value"].agg(["mean"])

# %%
plt.plot(np.array(df2["mean"]))

# %%
horizon = 10
adaptation_steps = 1
dataset = "BATTERY"
experiment_type = "VRAE"
df2 = df[(df['Experiment_id'].str.contains(experiment_type) ) & (df["Dataset"] == dataset) & (df["Horizon"] == horizon) & (df["Adaptation steps"]== adaptation_steps)].groupby(["Vrae weight", "Adaptation steps", "Horizon", "Task size"])["Value"].agg(["mean"])
plt.plot(np.array(df2["mean"]))

# %%
horizon = 10
adaptation_steps = 1
dataset = "BATTERY"
experiment_type = "NOISE"
df2 = df[(df['Experiment_id'].str.contains(experiment_type) ) & (df["Dataset"] == dataset) & (df["Horizon"] == horizon) & (df["Adaptation steps"]== adaptation_steps)].groupby(["Vrae weight", "Adaptation steps", "Horizon", "Task size"])["Value"].agg(["mean"])
plt.plot(np.array(df2["mean"]))
# Out:
#                                                     mean
# Vrae weight Adaptation steps Horizon Task size
# 0.000       1                10      50         0.002324
# 0.001       1                10      50         0.002128
# 0.010       1                10      50         0.002282
# 0.100       1                10      50         0.002616

# %%
horizon = 10
adaptation_steps = 1
dataset = "POLLUTION"
experiment_type = "VRAE"
df2 = df[(df['Experiment_id'].str.contains(experiment_type) ) & (df["Dataset"] == dataset) & (df["Horizon"] == horizon) & (df["Adaptation steps"]== adaptation_steps)].groupby(["Vrae weight", "Adaptation steps", "Horizon", "Task size"], as_index = False)["Value"].agg(["mean"])
df2 = df2.reset_index()

# %%
plt.plot(np.array(df2["mean"]))

# %%
horizon = 1
adaptation_steps = 0
dataset = "HR"
experiment_type = "NOISE"
var = "Noise level"
df2 = df[(df['Experiment_id'].str.contains(experiment_type) ) & (df["Dataset"] == dataset) & (df["Horizon"] == horizon) & (df["Adaptation steps"]== adaptation_steps)].groupby([var, "Adaptation steps", "Horizon", "Task size"], as_index = False)["Value"].agg(["mean"])
df2 = df2.reset_index()
plt.plot(np.array(df2["mean"]))

horizon = 1
adaptation_steps = 1
dataset = "HR"
experiment_type = "NOISE"
var = "Noise level"
df2 = df[(df['Experiment_id'].str.contains(experiment_type) ) & (df["Dataset"] == dataset) & (df["Horizon"] == horizon) & (df["Adaptation steps"]== adaptation_steps)].groupby([var, "Adaptation steps", "Horizon", "Task size"], as_index = False)["Value"].agg(["mean"])
df2 = df2.reset_index()
plt.plot(np.array(df2["mean"]))

# %%
df2
# Out:
#    Noise level  Adaptation steps  Horizon  Task size      mean
# 0        0.000                 1        1         50  0.045485
# 1        0.001                 1        1         50  0.047231
# 2        0.010                 1        1         50  0.045817
# 3        0.100                 1        1         50  0.050327

# %%
df2
# Out:
#    Vrae weight  Adaptation steps  Horizon  Task size      mean
# 0          0.0                 1       10         50  0.070329

# %%
df2 = df[(df['Experiment_id'].str.contains(experiment_type) ) & (df["Dataset"] == dataset) & (df["Horizon"] == horizon) & (df["Adaptation steps"]== adaptation_steps)].groupby(["Vrae weight", "Adaptation steps", "Horizon", "Task size", "Noise level"], as_index = False)["Value"].agg(["mean"])

# %%
df
# Out:
#         Experiment_id Model  Dataset  Learning rate  Noise level  Task size  \
# 0   HORIZON1_ABLATION  LSTM       HR           0.01          0.0         50
# 1   HORIZON1_ABLATION  LSTM       HR           0.01          0.0         50
# 2   HORIZON1_ABLATION  LSTM       HR           0.01          0.0         50
# 3   HORIZON1_ABLATION  LSTM       HR           0.01          0.0         50
# 4   HORIZON1_ABLATION  LSTM       HR           0.01          0.0         50
# ..                ...   ...      ...            ...          ...        ...
# 7      VRAE9_ABLATION  LSTM  BATTERY           0.01          0.0         50
# 8      VRAE9_ABLATION  LSTM  BATTERY           0.01          0.0         50
# 9      VRAE9_ABLATION  LSTM  BATTERY           0.01          0.0         50
# 10     VRAE9_ABLATION  LSTM  BATTERY           0.01          0.0         50
# 11     VRAE9_ABLATION  LSTM  BATTERY           0.01          0.0         50
#
#    Evaluation loss  Vrae weight Training  Meta-learning rate  ML-Horizon  \
# 0         MAE Test          0.0    MMAML              0.0005           1
# 1         MAE Test          0.0    MMAML              0.0005           1
# 2         MAE Test          0.0    MMAML              0.0005           1
# 3         MAE Test          0.0    MMAML              0.0005           1
# 4         MAE Test          0.0    MMAML              0.0005           1
# ..             ...          ...      ...                 ...         ...
# 7         MAE Test          0.1    MMAML              0.0005           1
# 8         MAE Test          0.1    MMAML              0.0005           1
# 9         MAE Test          0.1    MMAML              0.0005           1
# 10        MAE Test          0.1    MMAML              0.0005           1
# 11        MAE Test          0.1    MMAML              0.0005           1
#
#     Trial  Adaptation steps  Horizon     Value  Val error  Final_epoch
# 0       0                 1       10  0.083331   0.073623          157
# 1       0                 0       10  0.089711   0.085415          157
# 2       0                 1        1  0.062888        NaN          157
# 3       0                 0        1  0.081984        NaN          157
# 4       1                 1       10  0.086934   0.088309           51
# ..    ...               ...      ...       ...        ...          ...
# 7       1                 0        1  0.038311        NaN         1226
# 8       2                 1       10  0.001980   0.002263         1933
# 9       2                 0       10  0.044178   0.043989         1933
# 10      2                 1        1  0.002507        NaN         1933
# 11      2                 0        1  0.044501        NaN         1933
#
# [324 rows x 17 columns]

# %%
df2
# Out:
#                                                                 mean
# Vrae weight Adaptation steps Horizon Task size Noise level
# 0.0         1                10      50        0.000        0.068655
#                                                0.001        0.070001
#                                                0.010        0.069123
#                                                0.100        0.073537

# %%
df2 = df[df["Experiment_id"].str.contains("ABLATION_2")].groupby(["Vrae weight", "Adaptation steps", "Horizon", "Task size", "Noise level"], as_index = False)["Value"].agg(["mean"])
df2
# Out:
#                                                                 mean
# Vrae weight Adaptation steps Horizon Task size Noise level
# 0.000       0                1       50        0.0          0.005823
#                              10      50        0.0          0.005036
#             1                1       50        0.0          0.002338
#                              10      50        0.0          0.002124
# 0.001       0                1       50        0.0          0.005995
#                              10      50        0.0          0.005155
#             1                1       50        0.0          0.002367
#                              10      50        0.0          0.002121
# 0.010       0                1       50        0.0          0.005927
#                              10      50        0.0          0.005077
#             1                1       50        0.0          0.002522
#                              10      50        0.0          0.002220
# 0.100       0                1       50        0.0          0.006331
#                              10      50        0.0          0.005076
#             1                1       50        0.0          0.002531
#                              10      50        0.0          0.002417

# %%
horizon = 10
adaptation_steps = 1
dataset = "BATTERY"
experiment_type = "ABLATION_2"
var = "Vrae weight"
df2 = df[(df['Experiment_id'].str.contains(experiment_type) ) & (df["Dataset"] == dataset) & (df["Horizon"] == horizon) & (df["Adaptation steps"]== adaptation_steps)].groupby([var, "Adaptation steps", "Horizon", "Task size"], as_index = False)["Value"].agg(["mean"])
df2 = df2.reset_index()
plt.plot(np.array(df2["mean"]))
df2
# Out:
#    Vrae weight  Adaptation steps  Horizon  Task size      mean
# 0        0.000                 1       10         50  0.002124
# 1        0.001                 1       10         50  0.002121
# 2        0.010                 1       10         50  0.002220
# 3        0.100                 1       10         50  0.002417
