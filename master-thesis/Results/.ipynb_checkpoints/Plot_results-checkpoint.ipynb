# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
xgb_pollution = pd.read_csv("PRED_50_XGBOOST_D0_POLLUTION.csv")

# %%
resnet_pollution = pd.read_csv("PRED_50_RESNET_D0_POLLUTION.csv")

# %%
plt.plot(xgb_pollution.iloc[:,1])
plt.plot(xgb_pollution.iloc[:,2])
plt.plot(resnet_pollution.iloc[:,2])

# %%
max_n = 500
plt.plot(xgb_pollution.iloc[:max_n,1])
plt.plot(xgb_pollution.iloc[:max_n,2])
plt.plot(resnet_pollution.iloc[:max_n,2])
plt.legend(["True", "XGB", "Resnet"])

# %%
xgb_data = pd.read_csv("PRED_50_XGBOOST_D0_HR.csv")
resnet_data = pd.read_csv("PRED_50_RESNET_D0_HR.csv")
max_n = 500
plt.plot(xgb_data.iloc[:max_n,1])
plt.plot(xgb_data.iloc[:max_n,2])
plt.plot(resnet_data.iloc[:max_n,2])
plt.legend(["True", "XGB", "Resnet"])

# %%
xgb_data = pd.read_csv("PRED_50_XGBOOST_D0_HR.csv")
resnet_data = pd.read_csv("PRED_50_RESNET_D0_HR.csv")
max_n = 5000
plt.plot(xgb_data.iloc[:max_n,1])
plt.plot(xgb_data.iloc[:max_n,2])
plt.plot(resnet_data.iloc[:max_n,2])
plt.legend(["True", "XGB", "Resnet"])

# %%
xgb_data = pd.read_csv("PRED_50_XGBOOST_D0_BATTERY.csv")
resnet_data = pd.read_csv("PRED_50_RESNET_D0_BATTERY.csv")
max_n = 50000
plt.plot(xgb_data.iloc[:max_n,1])
plt.plot(xgb_data.iloc[:max_n,2])
plt.plot(resnet_data.iloc[:max_n,2])
plt.legend(["True", "XGB", "Resnet"])

# %%
resnet_data
# Out:
#        Unnamed: 0     TRUTH  PRED_RESNET
# 0               0  0.591190     0.582417
# 1               1  0.591255     0.576701
# 2               2  0.591347     0.581475
# 3               3  0.591467     0.587692
# 4               4  0.591541     0.593697
# ...           ...       ...          ...
# 11298       11298  0.182183     0.380916
# 11299       11299  0.182091     0.406950
# 11300       11300  0.181992     0.427995
# 11301       11301  0.181895     0.456544
# 11302       11302  0.181819     0.448070
#
# [11303 rows x 3 columns]

# %%
xgb_data
# Out:
#        Unnamed: 0     TRUTH  PRED_XGBOOST
# 0               0  0.591190      0.580280
# 1               1  0.591255      0.576103
# 2               2  0.591347      0.574852
# 3               3  0.591467      0.578631
# 4               4  0.591541      0.592336
# ...           ...       ...           ...
# 11298       11298  0.182183      0.010000
# 11299       11299  0.182091      0.010725
# 11300       11300  0.181992      0.012441
# 11301       11301  0.181895      0.013289
# 11302       11302  0.181819      0.012350
#
# [11303 rows x 3 columns]

# %%
#xgb_data = pd.read_csv("PRED_50_XGBOOST_D0_BATTERY.csv")
resnet_data = pd.read_csv("PRED_50_RESNET_D1_BATTERY.csv")
max_n = 50000
#plt.plot(xgb_data.iloc[:max_n,1])
plt.plot(resnet_data.iloc[:max_n,1])
plt.plot(resnet_data.iloc[:max_n,2])
plt.legend(["True", "XGB", "Resnet"])

# %%
N = resnet_data.iloc[:max_n,1].shape[0]
smoothed = np.convolve(x, np.ones((N,))/N, mode='same')
plt.plot(resnet_data.iloc[:max_n,1])
plt.plot(resnet_data.iloc[:max_n,2])
plt.legend(["True", "XGB", "Resnet"])
