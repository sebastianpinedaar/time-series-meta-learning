# %%
import matplotlib.pyplot as plt
from matplotlib.dates import date2num
import datetime
import numpy as np
x = [
    datetime.datetime(2011, 1, 4, 0, 0),
    datetime.datetime(2011, 1, 5, 0, 0),
    datetime.datetime(2011, 1, 6, 0, 0)
]
x = date2num(x)

y = [4, 9, 2]
z = [1, 2, 3]
k = [11, 12, 13]

ax = plt.subplot(111)
ax.bar(x-0.2, y, width=0.2, color='b', align='center')
ax.bar(x, z, width=0.2, color='g', align='center')
ax.bar(x+0.2, k, width=0.2, color='r', align='center')
ax.xaxis_date()

ax.set_xticklabels(["resnet", "vrada", "lstm"])

plt.show()

# %%
resnet_poll = [0.046249-0.049088, 0.045918-0.050184, 0.045918-0.051942, 0.046249-0.047287]
vradac_poll = [0.044605-0.044366, 0.043004-0.042831, 0.044605-0.043834, 0.043004-0.042978]
vradas_poll = [0.044031-0.043274, 0.042668-0.042291, 0.044031-0.045991, 0.042668-0.044174]
lstm_poll = [0.047803-0.046712, 0.044964-0.044580, 0.047803-0.046340, 0.044964-0.043697]
maml_poll = [0.045158-0.042198, 0.042444-0.041767, 0.045158-0.042343, 0.042444-0.041609]
mmaml_poll = [0.051570-0.040982, 0.051201-0.041663, 0.051570- 0.041127, 0.051201-0.042036]
models = ["Resnet", "VRADA-C", "VRADA-S", "LSTM", "MAML", "MMAML"]
cmap = plt.get_cmap("Set1")
x= np.array([1.5,3,4.5,6])
ax = plt.subplot(111)
ax.bar(x-0.6, resnet_poll, width=0.2, color=cmap(0.4), align='center')
ax.bar(x-0.4, vradac_poll, width=0.2, color=cmap(0.5), align='center')
ax.bar(x-0.2, vradas_poll, width=0.2, color=cmap(0.6), align='center')
ax.bar(x, lstm_poll, width=0.2, color=cmap(0.7), align='center')
ax.bar(x+0.2, maml_poll, width=0.2, color=cmap(0.8), align='center')
ax.bar(x+0.4, maml_poll, width=0.2, color=cmap(0.9), align='center')
plt.legend(models)
ax.set_xticks(x)
ax.set_xticklabels(["1S-1H", "1S-10H", "10S-1H", "10S-10H"])
# Out:
# [Text(0, 0, '1S-1H'),
#  Text(0, 0, '1S-10H'),
#  Text(0, 0, '10S-1H'),
#  Text(0, 0, '10S-10H')]

# %%
resnet = [0.061542-0.066982, 0.060816-0.081742, 0.061542-0.06250, 0.060816-0.073401]
vradac = [0.082923-0.078928, 0.080001-0.079924, 0.082923-0.076152, 0.080001-0.114041]
vradas = [0.085638-0.084661, 0.082110-0.101296, 0.085638-0.073838, 0.082110-0.096385]
lstm = [0.088224-0.067282, 0.081655-0.078787, 0.088224-0.056571, 0.081655-0.090629]
maml = [0.070878-0.063441, 0.071907-0.079240, 0.070878-0.051161, 0.071907-0.071135]
mmaml = [0.088667-0.044854, 0.102677-0.068922, 0.088667-0.050789,  0.102677-0.072903]
models = ["Resnet", "VRADA-C", "VRADA-S", "LSTM", "MAML", "MMAML"]
cmap = plt.get_cmap("Set1")
x= np.array([1.5,3,4.5,6])
ax = plt.subplot(111)
ax.bar(x-0.6, resnet, width=0.2, color=cmap(0.4), align='center')
ax.bar(x-0.4, vradac, width=0.2, color=cmap(0.5), align='center')
ax.bar(x-0.2, vradas, width=0.2, color=cmap(0.6), align='center')
ax.bar(x, lstm, width=0.2, color=cmap(0.7), align='center')
ax.bar(x+0.2, maml, width=0.2, color=cmap(0.8), align='center')
ax.bar(x+0.4, maml, width=0.2, color=cmap(0.9), align='center')
plt.legend(models)
ax.set_xticks(x)
ax.set_xticklabels(["1S-1H", "1S-10H", "10S-1H", "10S-10H"])
# Out:
# [Text(0, 0, '1S-1H'),
#  Text(0, 0, '1S-10H'),
#  Text(0, 0, '10S-1H'),
#  Text(0, 0, '10S-10H')]
